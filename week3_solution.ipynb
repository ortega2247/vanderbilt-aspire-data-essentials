# %%
import pandas as pd
import re

# %%
# Loading population df
pop_df = pd.read_csv('data/PEP_2017_PEPAGESEX.csv', skiprows=1)

# %%
# Loading cancer df
cancer_df = pd.read_csv('data/cancer_deaths.csv', skiprows=4, skipfooter=14,
                        engine='python')

# %%
# drop all April estimate columns

# %%
# Columns to keep
cols_to_keep = ['Geography']
for col in pop_df.columns:
    sep_words = col.split('-')
    if len(sep_words) == 4 and 'Total' in col and 'Both' in col:
        ages = sep_words[3]
        min_age = min(map(int, re.findall(r'\d+', ages)))
        if min_age >= 50:
            cols_to_keep.append(col)
    elif 'Median' in col and 'Both' in col:
        cols_to_keep.append(col)
    elif len(sep_words) == 3 and 'Total' in col and 'Both' in col:
        cols_to_keep.append(col)

# %%
pop_over50 = pop_df[cols_to_keep]

# %%
cols_to_drop = [col for col in pop_over50.columns if col.startswith('April') 
                 or '2011' in col or '2012' in col or '2013' in col
                or '2015' in col or '2016' in col]

# %%
pop_ready = pop_over50.drop(cols_to_drop, axis='columns')

# %%
def update_name(words):
    sep_words = words.split('-')
    if len(sep_words) == 3:
        year = sep_words[1]
        if 'Median' in words:
            new_name = 'median_age_' + year
        else:
            new_name = 'pop' + year + 'all'
    elif len(sep_words) == 4:
        year = sep_words[1]
        ages = list(map(int, re.findall(r'\d+', sep_words[-1])))
        if len(ages) == 2:
            new_name = 'pop{0}_{1}to{2}'.format(year, ages[0], ages[1])
        else:
            new_name = 'pop{0}_{1}over'.format(year, ages[0])
    else:
        new_name = 'County'
    return new_name

# %%
# Updating pop_ready names to

pop_ready.rename(update_name, axis='columns', inplace=True)

# %%
# Now we have to make the names of the county match
def remove_tn(county):
    county = county.split(',')
    only_county = county[0]
    return only_county

pop_ready['County'] = pop_ready['County'].apply(remove_tn)

# We drop the first two rows of the dataframe.
cancer_df.drop([0, 1], axis=0, inplace=True)

# %% [markdown]
# ## Use an outer join to merge pop_df and cancer data to a DataFrame called pop_and_cancer

# %%
# Sorting by county column to have the same order
pop_ready.sort_values(by=['County'], inplace=True)
cancer_df.sort_values(by=['County'], inplace=True)

# reset index after deleting rows and sorting
pop_ready.reset_index(drop=True, inplace=True)
cancer_df.reset_index(drop=True, inplace=True)

pop_and_cancer = pd.concat([pop_ready, cancer_df], join='outer', axis='columns')

# We drop one of the repeated County columns that is a result of joining the data frames
pop_and_cancer = pop_and_cancer.iloc[:, ~pop_and_cancer.columns.duplicated()]

# %% [markdown]
# ## Use the pandas series value_counts() method to create a dictionary called hospice_per_county. The key for this dict will be the county name and the value will be the count of hospice facilities in that county. Populate the dictionary for all TN counties by adding the counties with 0 hospice facilities to hospice_per_county.

# %%
# Loading hospice data
hospice_df = pd.read_csv('data/Hospice_General_Information.csv')

# Keep only the rows where facilities are in TN.
hospice_tn = hospice_df[hospice_df['State'] == 'TN']

# Keep only the Facility Name, Address Line 1, City, State, County Name, CMS Region, 
# Ownership Type, and Cerfification Date columns. 

hospice_ready = hospice_tn.drop(['CMS Certification Number (CCN)', 'Address Line 2', 
                 'Zip Code', 'PhoneNumber'], axis=1)

# Make all column names lower case and without spaces.
def lower_nospace(words):
    new_word = words.replace(" ", "")
    new_word = new_word.lower()
    return new_word

hospice_ready.rename(lower_nospace, axis='columns', inplace=True)

# %%
# Now we have to make the names of the county match
def add_county(county):
    county = county + ' County'
    return county

hospice_ready['countyname'] = hospice_ready['countyname'].apply(add_county)

# %%
hospice_county = hospice_ready['countyname'].value_counts().to_dict()
for county in pop_and_cancer['County'].values:
    if county in list(hospice_county.keys()):
        pass
    else:
        hospice_county[county] = 0

# %%
pop_and_cancer['hospice_per_county']= pop_and_cancer['County'].map(hospice_county)

# %%
pop_and_cancer.isnull().values.any()
# Out:
# False

# %%
pop_and_cancer
# Out:
#                County  pop 2010 all  pop 2014 all  pop 2017 all  \
# 0     Anderson County         75112         75131         76257
# 1      Bedford County         45086         46259         48117
# 2       Benton County         16511         16176         15986
# 3      Bledsoe County         12882         14419         14717
# 4       Blount County        123213        125827        129929
# 5      Bradley County         99096        102816        105560
# 6     Campbell County         40735         39895         39648
# 7       Cannon County         13801         13614         14216
# 8      Carroll County         28448         28358         27860
# 9       Carter County         57340         56270         56488
# 10    Cheatham County         39122         39604         40330
# 11     Chester County         17193         17101         17119
# 12   Claiborne County         32216         31529         31609
# 13        Clay County          7851          7639          7703
# 14       Cocke County         35641         35201         35556
# 15      Coffee County         52770         53521         55034
# 16    Crockett County         14588         14645         14473
# 17  Cumberland County         56197         57836         59078
# 18    Davidson County        627973        670314        691243
# 19      DeKalb County         18695         19219         19852
# 20     Decatur County         11718         11680         11751
# 21     Dickson County         49693         50473         52853
# 22        Dyer County         38318         37815         37463
# 23     Fayette County         38429         39031         40036
# 24    Fentress County         17920         17838         18136
# 25    Franklin County         40961         41268         41652
# 26      Gibson County         49734         49368         49111
# 27       Giles County         29420         28824         29401
# 28    Grainger County         22721         22865         23144
# 29      Greene County         68838         68440         68808
# ..                ...           ...           ...           ...
# 65       Obion County         31821         30815         30385
# 66     Overton County         22094         21948         22012
# 67       Perry County          7938          7819          7975
# 68     Pickett County          5073          5068          5073
# 69        Polk County         16817         16685         16757
# 70      Putnam County         72569         74913         77674
# 71        Rhea County         31857         32525         32691
# 72       Roane County         54157         52827         53036
# 73   Robertson County         66355         67869         70177
# 74  Rutherford County        263747        288608        317157
# 75       Scott County         22227         21986         21989
# 76  Sequatchie County         14127         14634         14736
# 77      Sevier County         89948         94570         97638
# 78      Shelby County        928552        938434        936961
# 79       Smith County         19125         19026         19636
# 80     Stewart County         13349         13218         13355
# 81    Sullivan County        156755        156513        157158
# 82      Sumner County        161199        172183        183545
# 83      Tipton County         61066         61566         61366
# 84   Trousdale County          7874          7993         10083
# 85      Unicoi County         18284         17905         17759
# 86       Union County         19118         18990         19442
# 87   Van Buren County          5569          5653          5742
# 88      Warren County         39860         39934         40651
# 89  Washington County        123386        125736        127806
# 90       Wayne County         16987         16788         16583
# 91     Weakley County         35042         33987         33337
# 92       White County         25821         26229         26753
# 93  Williamson County        184130        205213        226257
# 94      Wilson County        114677        125146        136442
#
#     pop 2010 _50to54  pop 2014 _50to54  pop 2017 _50to54  pop 2010 _55to59  \
# 0               5850              5690              5296              5577
# 1               3043              3207              3239              2646
# 2               1259              1204              1179              1224
# 3               1005              1216              1185               903
# 4               9152              9658              9522              8657
# 5               6967              7306              7216              6177
# 6               2883              2863              2866              2864
# 7               1093              1080              1081               930
# 8               1966              2044              1959              1945
# 9               4311              4195              4145              4099
# 10              3249              3397              3280              2723
# 11              1112              1132              1090               990
# 12              2374              2180              2262              2361
# 13               557               582               581               570
# 14              2784              2758              2618              2669
# 15              3841              3938              3796              3433
# 16              1043              1122              1019               901
# 17              3818              3901              3620              3783
# 18             42340             43565             40889             37772
# 19              1340              1437              1478              1323
# 20               860               856               795               852
# 21              3829              3872              3912              3196
# 22              2797              2727              2595              2497
# 23              3233              3182              2934              3098
# 24              1297              1301              1323              1334
# 25              2990              2982              2687              2936
# 26              3567              3565              3211              3206
# 27              2311              2334              2178              2152
# 28              1720              1693              1791              1627
# 29              5196              5108              4969              4885
# ..               ...               ...               ...               ...
# 65              2387              2171              1925              2257
# 66              1596              1518              1536              1558
# 67               601               511               506               590
# 68               364               387               394               385
# 69              1254              1274              1333              1178
# 70              4636              4681              4568              4329
# 71              2281              2216              2235              2113
# 72              4336              4088              3880              4367
# 73              5057              5349              5125              4338
# 74             16912             19172             19955             13802
# 75              1521              1530              1558              1446
# 76              1037              1064              1030               991
# 77              6759              7121              7151              6401
# 78             66350             64536             59532             59228
# 79              1506              1578              1540              1302
# 80              1024              1038              1085               989
# 81             12017             11716             11400             11519
# 82             11949             13104             13091             10627
# 83              4498              4741              4383              3796
# 84               605               599               639               562
# 85              1468              1349              1264              1409
# 86              1534              1500              1439              1321
# 87               465               414               376               472
# 88              2900              2888              2685              2603
# 89              8798              8772              8328              8183
# 90              1250              1238              1207              1104
# 91              2282              2210              2123              2205
# 92              1848              1869              1902              1849
# 93             15260             16295             16866             12386
# 94              8985              9840              9663              7687
#
#     pop 2014 _55to59  pop 2017 _55to59         ...          \
# 0               5689              5643         ...
# 1               2938              3143         ...
# 2               1239              1206         ...
# 3               1100              1197         ...
# 4               9094              9615         ...
# 5               6774              7199         ...
# 6               2810              2719         ...
# 7                994              1059         ...
# 8               1944              1968         ...
# 9               4273              4124         ...
# 10              2974              3224         ...
# 11              1099              1117         ...
# 12              2359              2218         ...
# 13               546               551         ...
# 14              2748              2780         ...
# 15              3710              3857         ...
# 16               964              1036         ...
# 17              4020              4243         ...
# 18             41623             41751         ...
# 19              1363              1434         ...
# 20               910               903         ...
# 21              3682              3836         ...
# 22              2566              2513         ...
# 23              3287              3364         ...
# 24              1321              1354         ...
# 25              3009              3024         ...
# 26              3305              3411         ...
# 27              2174              2285         ...
# 28              1691              1734         ...
# 29              5112              5105         ...
# ..               ...               ...         ...
# 65              2290              2202         ...
# 66              1574              1557         ...
# 67               606               569         ...
# 68               364               394         ...
# 69              1251              1212         ...
# 70              4554              4689         ...
# 71              2250              2256         ...
# 72              4400              4274         ...
# 73              4770              5244         ...
# 74             16414             18303         ...
# 75              1464              1426         ...
# 76              1112              1113         ...
# 77              6893              7145         ...
# 78             62411             60997         ...
# 79              1392              1505         ...
# 80              1013               981         ...
# 81             11767             11474         ...
# 82             11672             12739         ...
# 83              4197              4395         ...
# 84               597               616         ...
# 85              1440              1413         ...
# 86              1446              1588         ...
# 87               477               457         ...
# 88              2772              2839         ...
# 89              8524              8793         ...
# 90              1146              1202         ...
# 91              2173              2120         ...
# 92              1844              1835         ...
# 93             14701             15563         ...
# 94              8802              9711         ...
#
#     Met Healthy People Objective of 161.4?  \
# 0                                       No
# 1                                       No
# 2                                       No
# 3                                       No
# 4                                       No
# 5                                       No
# 6                                       No
# 7                                       No
# 8                                       No
# 9                                       No
# 10                                      No
# 11                                      No
# 12                                      No
# 13                                      No
# 14                                      No
# 15                                      No
# 16                                      No
# 17                                      No
# 18                                      No
# 19                                      No
# 20                                      No
# 21                                      No
# 22                                      No
# 23                                     Yes
# 24                                      No
# 25                                      No
# 26                                      No
# 27                                      No
# 28                                      No
# 29                                      No
# ..                                     ...
# 65                                      No
# 66                                      No
# 67                                      No
# 68                                     Yes
# 69                                      No
# 70                                      No
# 71                                      No
# 72                                      No
# 73                                      No
# 74                                      No
# 75                                      No
# 76                                      No
# 77                                      No
# 78                                      No
# 79                                      No
# 80                                      No
# 81                                      No
# 82                                     Yes
# 83                                      No
# 84                                      No
# 85                                      No
# 86                                      No
# 87                                     Yes
# 88                                      No
# 89                                      No
# 90                                      No
# 91                                      No
# 92                                      No
# 93                                     Yes
# 94                                      No
#
#     Age-Adjusted Death Rate - deaths per 100,000  \
# 0                                          180.6
# 1                                          182.7
# 2                                          233.9
# 3                                          170.0
# 4                                          168.2
# 5                                          183.0
# 6                                          219.2
# 7                                          202.4
# 8                                          221.8
# 9                                          176.2
# 10                                         239.6
# 11                                         178.4
# 12                                         237.3
# 13                                         209.1
# 14                                         222.1
# 15                                         194.2
# 16                                         164.1
# 17                                         174.4
# 18                                         184.7
# 19                                         178.8
# 20                                         208.7
# 21                                         201.1
# 22                                         182.9
# 23                                         154.3
# 24                                         211.1
# 25                                         184.1
# 26                                         202.0
# 27                                         193.7
# 28                                         222.0
# 29                                         185.6
# ..                                           ...
# 65                                         214.1
# 66                                         217.0
# 67                                         216.0
# 68                                         158.7
# 69                                         209.5
# 70                                         201.5
# 71                                         194.9
# 72                                         185.2
# 73                                         187.2
# 74                                         170.3
# 75                                         241.0
# 76                                         224.3
# 77                                         186.7
# 78                                         195.0
# 79                                         192.2
# 80                                         218.2
# 81                                         181.4
# 82                                         161.2
# 83                                         210.6
# 84                                         265.5
# 85                                         199.8
# 86                                         234.2
# 87                                         160.3
# 88                                         200.3
# 89                                         180.5
# 90                                         207.4
# 91                                         187.0
# 92                                         216.3
# 93                                         127.2
# 94                                         170.5
#
#     Lower 95% Confidence Interval  Upper 95% Confidence Interval  \
# 0                           169.1                          192.7
# 1                           166.1                          200.6
# 2                           207.1                          263.6
# 3                           143.5                          200.6
# 4                           159.4                          177.4
# 5                           172.2                          194.3
# 6                           201.8                          237.7
# 7                           174.2                          234.3
# 8                           201.2                          244.1
# 9                           163.4                          189.9
# 10                          217.8                          263.0
# 11                          153.5                          206.5
# 12                          216.4                          259.8
# 13                          174.1                          250.3
# 14                          203.5                          242.2
# 15                          179.4                          209.9
# 16                          139.1                          192.7
# 17                          162.5                          187.0
# 18                          179.8                          189.7
# 19                          155.4                          204.9
# 20                          179.4                          242.1
# 21                          184.9                          218.4
# 22                          165.7                          201.4
# 23                          139.1                          170.7
# 24                          185.3                          239.8
# 25                          168.4                          201.0
# 26                          186.6                          218.3
# 27                          174.5                          214.7
# 28                          197.9                          248.4
# 29                          173.4                          198.4
# ..                            ...                            ...
# 65                          194.6                          235.2
# 66                          193.8                          242.4
# 67                          178.5                          259.9
# 68                          123.3                          203.9
# 69                          183.6                          238.4
# 70                          188.2                          215.5
# 71                          176.0                          215.4
# 72                          172.0                          199.3
# 73                          173.0                          202.3
# 74                          162.5                          178.4
# 75                          214.5                          270.0
# 76                          194.3                          257.9
# 77                          175.6                          198.3
# 78                          190.8                          199.2
# 79                          166.8                          220.6
# 80                          188.3                          252.0
# 81                          173.6                          189.5
# 82                          153.0                          169.6
# 83                          194.5                          227.6
# 84                          219.0                          319.1
# 85                          176.9                          225.3
# 86                          206.1                          265.3
# 87                          122.7                          207.4
# 88                          183.0                          219.0
# 89                          171.1                          190.3
# 90                          181.4                          236.4
# 91                          168.9                          206.6
# 92                          195.1                          239.4
# 93                          119.8                          134.9
# 94                          160.4                          181.0
#
#     Average Annual Count  Recent Trend  Recent 5-Year Trend in Death Rates  \
# 0                    195       falling                                -0.7
# 1                     92       falling                                -0.7
# 2                     59        stable                                 0.3
# 3                     31       falling                                -1.3
# 4                    283       falling                                -0.9
# 5                    220       falling                                -1.0
# 6                    124        stable                                -0.4
# 7                     38        stable                                -0.2
# 8                     89        stable                                -0.2
# 9                    145       falling                                -1.0
# 10                    97        stable                                -0.6
# 11                    38        stable                                -0.4
# 12                   100        stable                                -0.1
# 13                    26        stable                                -1.0
# 14                   110        stable                                -0.5
# 15                   131       falling                                -0.7
# 16                    31        stable                                -0.5
# 17                   182       falling                                -0.8
# 18                  1137       falling                                -1.5
# 19                    44        stable                                -0.6
# 20                    39        stable                                -0.2
# 21                   117       falling                                -0.6
# 22                    86       falling                                -0.6
# 23                    81       falling                                -1.4
# 24                    52        stable                                -0.5
# 25                   105       falling                                -0.8
# 26                   132        stable                                -0.4
# 27                    78        stable                                -0.7
# 28                    66        stable                                 0.1
# 29                   181       falling                                -3.2
# ..                   ...           ...                                 ...
# 65                    92        stable                                 0.0
# 66                    67        stable                                -0.3
# 67                    25        stable                                 0.0
# 68                    15        stable                                -0.5
# 69                    50        stable                                -0.8
# 70                   176        stable                                -0.2
# 71                    82       falling                                -0.7
# 72                   152       falling                                -0.7
# 73                   135       falling                                -0.8
# 74                   380       falling                                -1.4
# 75                    63        stable                                -0.5
# 76                    43        rising                                 1.3
# 77                   224       falling                                -0.5
# 78                  1767       falling                                -1.1
# 79                    43        stable                                -6.7
# 80                    40        stable                                 0.1
# 81                   425       falling                                -0.7
# 82                   305       falling                                -2.2
# 83                   134        stable                                -0.2
# 84                    24        stable                                 0.0
# 85                    58        stable                                 0.1
# 86                    53        stable                                -0.5
# 87                    14        stable                                -0.9
# 88                   100        stable                                -0.1
# 89                   284       falling                                -1.2
# 90                    47        stable                                 0.1
# 91                    81        stable                                -0.3
# 92                    79        stable                                -0.6
# 93                   239       falling                                -3.8
# 94                   229       falling                                -2.0
#
#     Lower 95% Confidence Interval.1  Upper 95% Confidence Interval.1  \
# 0                              -1.2                             -0.2
# 1                              -1.4                             -0.1
# 2                              -0.4                              1.1
# 3                              -2.3                             -0.3
# 4                              -1.3                             -0.4
# 5                              -1.4                             -0.5
# 6                              -0.8                              0.0
# 7                              -1.1                              0.7
# 8                              -0.7                              0.2
# 9                              -1.6                             -0.4
# 10                             -1.4                              0.3
# 11                             -1.5                              0.8
# 12                             -0.7                              0.4
# 13                             -2.0                              0.0
# 14                             -1.0                              0.0
# 15                             -1.2                             -0.2
# 16                             -1.3                              0.4
# 17                             -1.3                             -0.3
# 18                             -1.7                             -1.2
# 19                             -1.4                              0.3
# 20                             -1.2                              0.8
# 21                             -1.0                             -0.2
# 22                             -1.1                             -0.1
# 23                             -2.2                             -0.5
# 24                             -1.2                              0.3
# 25                             -1.3                             -0.2
# 26                             -1.0                              0.2
# 27                             -1.5                              0.1
# 28                             -0.7                              1.0
# 29                             -4.9                             -1.5
# ..                              ...                              ...
# 65                             -0.5                              0.6
# 66                             -1.1                              0.5
# 67                             -1.4                              1.5
# 68                             -1.8                              0.9
# 69                             -1.9                              0.3
# 70                             -0.7                              0.3
# 71                             -1.3                             -0.2
# 72                             -1.1                             -0.3
# 73                             -1.3                             -0.2
# 74                             -1.7                             -1.1
# 75                             -1.1                              0.1
# 76                              0.3                              2.3
# 77                             -0.9                             -0.1
# 78                             -1.2                             -1.0
# 79                            -13.8                              1.0
# 80                             -1.2                              1.4
# 81                             -1.1                             -0.4
# 82                             -3.6                             -0.8
# 83                             -0.8                              0.3
# 84                             -1.3                              1.3
# 85                             -0.6                              0.7
# 86                             -1.2                              0.2
# 87                             -2.4                              0.6
# 88                             -0.8                              0.5
# 89                             -1.6                             -0.8
# 90                             -0.6                              0.9
# 91                             -0.8                              0.3
# 92                             -1.3                              0.0
# 93                             -4.8                             -2.9
# 94                             -2.8                             -1.2
#
#     hospice_per_county
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    1
# 5                    2
# 6                    0
# 7                    0
# 8                    2
# 9                    1
# 10                   0
# 11                   0
# 12                   1
# 13                   0
# 14                   1
# 15                   1
# 16                   0
# 17                   1
# 18                   8
# 19                   0
# 20                   0
# 21                   0
# 22                   0
# 23                   1
# 24                   1
# 25                   0
# 26                   0
# 27                   0
# 28                   0
# 29                   0
# ..                 ...
# 65                   1
# 66                   0
# 67                   1
# 68                   0
# 69                   0
# 70                   1
# 71                   0
# 72                   0
# 73                   2
# 74                   1
# 75                   0
# 76                   0
# 77                   0
# 78                   5
# 79                   0
# 80                   0
# 81                   1
# 82                   1
# 83                   0
# 84                   0
# 85                   0
# 86                   0
# 87                   0
# 88                   0
# 89                   2
# 90                   1
# 91                   0
# 92                   0
# 93                   2
# 94                   0
#
# [95 rows x 42 columns]
